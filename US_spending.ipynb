# %%
import json
import requests
import pandas as pd
import numpy as np

import sqlite3

# %%
page = 1
url = 'https://api.usaspending.gov/api/v1/awards/?limit=500&page=' + str(page)



params = {
    "filters": [
      {
        "field": "date_signed",
        "operation": "greater_than_or_equal",
        "value": "2017-01-01"
      },
      {
        "field": "date_signed",
        "operation": "less_than",
        "value": "2017-12-31"
      }, 
      {
        "field": "category",
        "operation": "equals",
        "value": "contract"
      },
      {
        "field": "awarding_agency__toptier_agency__cgac_code",
        "operation": "in",
        "value": ["012", "069", "014"]
      },
        {
        "field": "place_of_performance__country_name",
        "operation": "equals",
        "value": "UNITED STATES"
        }]
}

# %%
us_data = requests.get(url , json =params).json()
# print(json.dumps(us_data, indent=4, sort_keys=True))

# %%
us_dict = {}
us_dict['Awarding_Agency'] = []
us_dict['Subtier_Agency'] = []
us_dict['Subtier_Code'] = []
us_dict['Category'] = []
us_dict['POP_City'] = []
us_dict['POP_State'] = []
us_dict['POP_Zip'] = []
us_dict['Recipient_Name'] = []
us_dict['Total_Obligation'] = []

next_page = us_data['page_metadata']['has_next_page']
print(next_page)
print(len(us_data['results']))
# Out:
# True
# 500

# %%
# for contract in us_data['results']:
#     page += 1
#     url = 'https://api.usaspending.gov/api/v1/awards/?limit=500&page=' + str(page)
#     print(us_data['page_metadata']['page'])
#     print(contract['awarding_agency']['toptier_agency']['name'])

#     try:
#         us_dict['Awarding_Agency'].append(contract['awarding_agency']['toptier_agency']['name'])
#     except:
#         us_dict['Awarding_Agency'].append(np.nan)
#     try:
#         us_dict['Subtier_Agency'].append(contract['awarding_agency']['subtier_agency']['name'])
#     except:
#         us_dict['Subtier_Agency'].append(np.nan)
#     try:
#         us_dict['Subtier_Code'].append(contract['awarding_agency']['subtier_agency']['subtier_code'])
#     except:
#         us_dict['Subtier_Code'].append(np.nan)
#     try:
#         us_dict['Category'].append(contract['category'])
#     except:
#         us_dict['Category'].append(np.nan)
#     try:
#         us_dict['POP_City'].append(contract['place_of_performance']['city_name'])
#     except:
#         us_dict['POP_City'].append(np.nan)
#     try:
#         us_dict['POP_State'].append(contract['place_of_performance']['state_name'])
#     except:
#         us_dict['POP_State'].append(np.nan)
#     try:
#         us_dict['POP_Zip'].append(contract['place_of_performance']['zip5'])
#     except:
#         us_dict['POP_Zip'].append(np.nan)
#     try:
#         us_dict['Recipient_Name'].append(contract['recipient']['recipient_name'])
#     except:
#         us_dict['Recipient_Name'].append(np.nan)
#     try:
#         us_dict['Total_Obligation'].append(contract['total_obligation'])
#     except:
#         us_dict['Total_Obligation'].append(np.nan)

# %%
while next_page:
    for contract in us_data['results']:
        try:
            us_dict['Awarding_Agency'].append(contract['awarding_agency']['toptier_agency']['name'])
        except:
            us_dict['Awarding_Agency'].append(np.nan)
        try:
            us_dict['Subtier_Agency'].append(contract['awarding_agency']['subtier_agency']['name'])
        except:
            us_dict['Subtier_Agency'].append(np.nan)
        try:
            us_dict['Subtier_Code'].append(contract['awarding_agency']['subtier_agency']['subtier_code'])
        except:
            us_dict['Subtier_Code'].append(np.nan)
        try:
            us_dict['Category'].append(contract['category'])
        except:
            us_dict['Category'].append(np.nan)
        try:
            us_dict['POP_City'].append(contract['place_of_performance']['city_name'])
        except:
            us_dict['POP_City'].append(np.nan)
        try:
            us_dict['POP_State'].append(contract['place_of_performance']['state_name'])
        except:
            us_dict['POP_State'].append(np.nan)
        try:
            us_dict['POP_Zip'].append(contract['place_of_performance']['zip5'])
        except:
            us_dict['POP_Zip'].append(np.nan)
        try:
            us_dict['Recipient_Name'].append(contract['recipient']['recipient_name'])
        except:
            us_dict['Recipient_Name'].append(np.nan)
        try:
            us_dict['Total_Obligation'].append(contract['total_obligation'])
        except:
            us_dict['Total_Obligation'].append(np.nan)
    page += 1
    url = 'https://api.usaspending.gov/api/v1/awards/?limit=500&page=' + str(page)
    print(us_data['page_metadata']['page'])
    print(contract['awarding_agency']['toptier_agency']['name'])
    us_data = requests.get(url , json =params).json()
    next_page = us_data['page_metadata']['has_next_page']
        
for contract in us_data['results']:
    print(str(us_data['page_metadat']['page']) + ' LAST PAGE')

    try:
        us_dict['Awarding_Agency'].append(contract['awarding_agency']['toptier_agency']['name'])
    except:
        us_dict['Awarding_Agency'].append(np.nan)
    try:
        us_dict['Subtier_Agency'].append(contract['awarding_agency']['subtier_agency']['name'])
    except:
        us_dict['Subtier_Agency'].append(np.nan)
    try:
        us_dict['Subtier_Code'].append(contract['awarding_agency']['subtier_agency']['subtier_code'])
    except:
        us_dict['Subtier_Code'].append(np.nan)
    try:
        us_dict['Category'].append(contract['category'])
    except:
        us_dict['Category'].append(np.nan)
    try:
        us_dict['POP_City'].append(contract['place_of_performance']['city_name'])
    except:
        us_dict['POP_City'].append(np.nan)
    try:
        us_dict['POP_State'].append(contract['place_of_performance']['state_name'])
    except:
        us_dict['POP_State'].append(np.nan)
    try:
        us_dict['POP_Zip'].append(contract['place_of_performance']['zip5'])
    except:
        us_dict['POP_Zip'].append(np.nan)
    try:
        us_dict['Recipient_Name'].append(contract['recipient']['recipient_name'])
    except:
        us_dict['Recipient_Name'].append(np.nan)
    try:
        us_dict['Total_Obligation'].append(contract['total_obligation'])
    except:
        us_dict['Total_Obligation'].append(np.nan)
# Out:
# 1
# Department of Transportation
# 2
# Department of Transportation
# 3
# Department of Transportation
# 4
# Department of Transportation
# 5
# Department of Transportation
# 6
# Department of Agriculture
# 7
# Department of Agriculture
# 8
# Department of Agriculture
# 9
# Department of Agriculture
# 10
# Department of Agriculture
# 11
# Department of Agriculture
# 12
# Department of Agriculture
# 13
# Department of Agriculture
# 14
# Department of Agriculture
# 15
# Department of Agriculture
# 16
# Department of Agriculture
# 17
# Department of Agriculture
# 18
# Department of Agriculture
# 19
# Department of Agriculture
# 20
# Department of Agriculture
# 21
# Department of the Interior
# 22
# Department of the Interior
# 23
# Department of the Interior
# 24
# Department of the Interior
# 25
# Department of the Interior
# 26
# Department of Transportation
# 27
# Department of Transportation
# 28
# Department of Transportation
# 29
# Department of Transportation
# 30
# Department of Transportation
# 31
# Department of Agriculture
# 32
# Department of Agriculture
# 33
# Department of Agriculture
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-473dffeaf41d> in <module>()
#      41     print(us_data['page_metadata']['page'])
#      42     print(contract['awarding_agency']['toptier_agency']['name'])
# ---> 43     us_data = requests.get(url , json =params).json()
#      44     next_page = us_data['page_metadata']['has_next_page']
#      45
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1622             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1623         else:
# -> 1624             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1625         self._raise_ssl_error(self._ssl, result)
#    1626
#
# KeyboardInterrupt:

# %%
us_data_df = pd.DataFrame(us_dict)
us_data_df
# Out:
#                     Awarding_Agency  Category                   POP_City  \
# 0      Department of Transportation  contract                 WASHINGTON
# 1      Department of Transportation  contract                  BALTIMORE
# 2      Department of Transportation  contract                  BALTIMORE
# 3      Department of Transportation  contract                    ORLANDO
# 4      Department of Transportation  contract                     MOJAVE
# 5      Department of Transportation  contract                   FLUSHING
# 6      Department of Transportation  contract                     DALLAS
# 7      Department of Transportation  contract           SAINT PETERSBURG
# 8      Department of Transportation  contract              OKLAHOMA CITY
# 9      Department of Transportation  contract                 WASHINGTON
# 10     Department of Transportation  contract                     TUSTIN
# 11     Department of Transportation  contract              OKLAHOMA CITY
# 12     Department of Transportation  contract           COLORADO SPRINGS
# 13     Department of Transportation  contract                   FLUSHING
# 14     Department of Transportation  contract                   PRESCOTT
# 15     Department of Transportation  contract              OKLAHOMA CITY
# 16     Department of Transportation  contract                     NORMAN
# 17     Department of Transportation  contract              OKLAHOMA CITY
# 18     Department of Transportation  contract              OKLAHOMA CITY
# 19     Department of Transportation  contract              NICHOLS HILLS
# 20     Department of Transportation  contract                   FLUSHING
# 21     Department of Transportation  contract              OKLAHOMA CITY
# 22     Department of Transportation  contract              OKLAHOMA CITY
# 23     Department of Transportation  contract              OKLAHOMA CITY
# 24     Department of Transportation  contract                      BOISE
# 25     Department of Transportation  contract                 THE COLONY
# 26     Department of Transportation  contract                 LOUISVILLE
# 27     Department of Transportation  contract                   FLUSHING
# 28     Department of Transportation  contract              OVERLAND PARK
# 29     Department of Transportation  contract              OKLAHOMA CITY
# ...                             ...       ...                        ...
# 73970    Department of the Interior  contract                 NINETY SIX
# 73971    Department of the Interior  contract            KING OF PRUSSIA
# 73972    Department of the Interior  contract                     QUINCY
# 73973    Department of the Interior  contract                 WASHINGTON
# 73974    Department of the Interior  contract                HODGENVILLE
# 73975    Department of the Interior  contract                    NATCHEZ
# 73976    Department of the Interior  contract                 BLACKSBURG
# 73977    Department of the Interior  contract                    ST JOHN
# 73978    Department of the Interior  contract                    CHICAGO
# 73979    Department of the Interior  contract           SOUTHWEST HARBOR
# 73980    Department of the Interior  contract                 SPRINGDALE
# 73981    Department of the Interior  contract                 GLEN ARBOR
# 73982    Department of the Interior  contract  YELLOWSTONE NATIONAL PARK
# 73983    Department of the Interior  contract                MIDDLESBORO
# 73984    Department of the Interior  contract                  VANCOUVER
# 73985    Department of the Interior  contract                  CAMBRIDGE
# 73986    Department of the Interior  contract                   SCRANTON
# 73987    Department of the Interior  contract                 HAYNEVILLE
# 73988    Department of the Interior  contract                 SPRINGDALE
# 73989    Department of the Interior  contract                   MUNISING
# 9                        Federal Aviation Administration         6920
# 10                       Federal Aviation Administration         6920
# 11                       Federal Aviation Administration         6920
# 12                       Federal Aviation Administration         6920
# 13                       Federal Aviation Administration         6920
# 14                       Federal Aviation Administration         6920
# 15                       Federal Aviation Administration         6920
# 16                       Federal Aviation Administration         6920
# 17                       Federal Aviation Administration         6920
# 18                       Federal Aviation Administration         6920
# 19                       Federal Aviation Administration         6920
# 20                       Federal Aviation Administration         6920
# 21                       Federal Aviation Administration         6920
# 22                       Federal Aviation Administration         6920
# 23                       Federal Aviation Administration         6920
# 24                       Federal Aviation Administration         6920
# 25                       Federal Aviation Administration         6920
# 26                       Federal Aviation Administration         6920
# 27                       Federal Aviation Administration         6920
# 28                       Federal Aviation Administration         6920
# 29                       Federal Aviation Administration         6920
# ...                                                  ...          ...
# 73970                              National Park Service         1443
# 73971                              National Park Service         1443
# 73972                              National Park Service         1443
# 73973                              National Park Service         1443
# 73974                              National Park Service         1443
# 73975                              National Park Service         1443
# 73976                              National Park Service         1443
# 73977                              National Park Service         1443
# 73978                              National Park Service         1443
# 73979                              National Park Service         1443
# 73980                              National Park Service         1443
# 73981                              National Park Service         1443
# 73982                              National Park Service         1443
# 73983                              National Park Service         1443
# 73984                              National Park Service         1443
# 73985                              National Park Service         1443
# 73986                              National Park Service         1443
# 73987                              National Park Service         1443
# 73988                              National Park Service         1443
# 73989                              National Park Service         1443
# 73990                              National Park Service         1443
# 73991                              National Park Service         1443
# 73992                              National Park Service         1443
# 73993                              National Park Service         1443
# 73994                              National Park Service         1443
# 73995                              National Park Service         1443
# 73996                              National Park Service         1443
# 73997                              National Park Service         1443
# 73998                              National Park Service         1443
# 73999                              National Park Service         1443
#
#       Total_Obligation
# 0            745068.00
# 1            520169.00
# 2            662420.00
# 3             39520.00
# 4             29950.00
# 5             59200.00
# 6              7693.00
# 7            211847.00
# 8             13989.00
# 9            490200.00
# 10           106500.00
# 11           605377.86
# 12            15830.00
# 13           196080.00
# 14            13675.12
# 15            68160.00
# 16          2673732.36
# 17                0.00
# 18           477978.00
# 19            68000.00
# 20            37000.00
# 21             3672.00
# 22             4527.95
# 23          1704732.69
# 24            12770.00
# 25             5630.01
# 26           612708.00
# 27            15222.00
# 28            77471.16
# 29            12300.00
# ...                ...
# 73970        158366.01
# 73971        201400.23
# 73972        201858.58
# 73973        117977.00
# 73974         79920.00
# 73975         93402.48
# 73976        319694.14
# 73977        362321.16
# 73978        152552.04
# 73979        424012.00
# 73980        384167.00
# 73981       1544118.83
# 73982         12595.00
# 73983        121280.38
# 73984        485820.00
# 73985         99600.00
# 73986        385320.00
# 73987         31600.00
# 73988        234352.00
# 73989         24998.00
# 73990         55600.00
# 73991       1087500.00
# 73992        230353.86
# 73993       1768922.00
# 73994         21694.68
# 73995         22630.00
# 73996        519230.00
# 73997         50000.00
# 73998        142418.03
# 73999        211500.00
#
# [74000 rows x 9 columns]

# %%
# us_data_df.to_csv('us_data.csv')

conn = sqlite3.connect('us_data2.sqlite')

us_data_df.to_sql("department_contracts", conn, if_exists="replace")

# %%
import json
import requests
import pandas as pd
import numpy as np

# %%
page = 1
url = 'https://api.usaspending.gov/api/v1/awards/?limit=500&page=' + str(page)



params = {
    "filters": [
      {
        "field": "date_signed",
        "operation": "greater_than_or_equal",
        "value": "2017-01-01"
      },
      {
        "field": "date_signed",
        "operation": "less_than",
        "value": "2017-12-31"
      }, 
      {
        "field": "category",
        "operation": "equals",
        "value": "contract"
      },
      {
        "field": "awarding_agency__toptier_agency__cgac_code",
        "operation": "in",
        "value": ["012", "069", "014"]
      },
        {
        "field": "place_of_performance__country_name",
        "operation": "equals",
        "value": "UNITED STATES"
        }]
}

# %%
us_data = requests.get(url , json =params).json()
print(json.dumps(us_data, indent=4, sort_keys=True))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
us_dict = {}
us_dict['Awarding_Agency'] = []
us_dict['Subtier_Agency'] = []
us_dict['Subtier_Code'] = []
us_dict['Category'] = []
us_dict['POP_City'] = []
us_dict['POP_State'] = []
us_dict['POP_Zip'] = []
us_dict['Recipient_Name'] = []
us_dict['Total_Obligation'] = []

next_page = us_data['page_metadata']['has_next_page']
print(next_page)
print(len(us_data['results']))
# Out:
# True
# 500

# %%
for contract in us_data['results']:
    page += 1
    url = 'https://api.usaspending.gov/api/v1/awards/?limit=500&page=' + str(page)
    print(us_data['page_metadata']['page'])
    print(contract['awarding_agency']['toptier_agency']['name'])

    try:
        us_dict['Awarding_Agency'].append(contract['awarding_agency']['toptier_agency']['name'])
    except:
        us_dict['Awarding_Agency'].append(np.nan)
    try:
        us_dict['Subtier_Agency'].append(contract['awarding_agency']['subtier_agency']['name'])
    except:
        us_dict['Subtier_Agency'].append(np.nan)
    try:
        us_dict['Subtier_Code'].append(contract['awarding_agency']['subtier_agency']['subtier_code'])
    except:
        us_dict['Subtier_Code'].append(np.nan)
    try:
        us_dict['Category'].append(contract['category'])
    except:
        us_dict['Category'].append(np.nan)
    try:
        us_dict['POP_City'].append(contract['place_of_performance']['city_name'])
    except:
        us_dict['POP_City'].append(np.nan)
    try:
        us_dict['POP_State'].append(contract['place_of_performance']['state_name'])
    except:
        us_dict['POP_State'].append(np.nan)
    try:
        us_dict['POP_Zip'].append(contract['place_of_performance']['zip5'])
    except:
        us_dict['POP_Zip'].append(np.nan)
    try:
        us_dict['Recipient_Name'].append(contract['recipient']['recipient_name'])
    except:
        us_dict['Recipient_Name'].append(np.nan)
    try:
        us_dict['Total_Obligation'].append(contract['total_obligation'])
    except:
        us_dict['Total_Obligation'].append(np.nan)
# Out:
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation
# 1
# Department of Transportation

# %%
# while next_page:
#     for contract in us_data['results']:
#         page += 1
#         url = 'https://api.usaspending.gov/api/v1/awards/?limit=500&page=' + str(page)
#         print(us_data['page_metadata']['page'])
#         print(contract['awarding_agency']['toptier_agency']['name'])

#         try:
#             us_dict['Awarding_Agency'].append(contract['awarding_agency']['toptier_agency']['name'])
#         except:
#             us_dict['Awarding_Agency'].append(np.nan)
#         try:
#             us_dict['Subtier_Agency'].append(contract['awarding_agency']['subtier_agency']['name'])
#         except:
#             us_dict['Subtier_Agency'].append(np.nan)
#         try:
#             us_dict['Subtier_Code'].append(contract['awarding_agency']['subtier_agency']['subtier_code'])
#         except:
#             us_dict['Subtier_Code'].append(np.nan)
#         try:
#             us_dict['Category'].append(contract['category'])
#         except:
#             us_dict['Category'].append(np.nan)
#         try:
#             us_dict['POP_City'].append(contract['place_of_performance']['city_name'])
#         except:
#             us_dict['POP_City'].append(np.nan)
#         try:
#             us_dict['POP_State'].append(contract['place_of_performance']['state_name'])
#         except:
#             us_dict['POP_State'].append(np.nan)
#         try:
#             us_dict['POP_Zip'].append(contract['place_of_performance']['zip5'])
#         except:
#             us_dict['POP_Zip'].append(np.nan)
#         try:
#             us_dict['Recipient_Name'].append(contract['recipient']['recipient_name'])
#         except:
#             us_dict['Recipient_Name'].append(np.nan)
#         try:
#             us_dict['Total_Obligation'].append(contract['total_obligation'])
#         except:
#             us_dict['Total_Obligation'].append(np.nan)

#         us_data = requests.get(url , json =params).json()
#         next_page = us_data['page_metadata']['has_next_page']
        
# for contract in us_data['results']:
#     print(str(us_data['page_metadat']['page']) + ' LAST PAGE')

#     try:
#         us_dict['Awarding_Agency'].append(contract['awarding_agency']['toptier_agency']['name'])
#     except:
#         us_dict['Awarding_Agency'].append(np.nan)
#     try:
#         us_dict['Subtier_Agency'].append(contract['awarding_agency']['subtier_agency']['name'])
#     except:
#         us_dict['Subtier_Agency'].append(np.nan)
#     try:
#         us_dict['Subtier_Code'].append(contract['awarding_agency']['subtier_agency']['subtier_code'])
#     except:
#         us_dict['Subtier_Code'].append(np.nan)
#     try:
#         us_dict['Category'].append(contract['category'])
#     except:
#         us_dict['Category'].append(np.nan)
#     try:
#         us_dict['POP_City'].append(contract['place_of_performance']['city_name'])
#     except:
#         us_dict['POP_City'].append(np.nan)
#     try:
#         us_dict['POP_State'].append(contract['place_of_performance']['state_name'])
#     except:
#         us_dict['POP_State'].append(np.nan)
#     try:
#         us_dict['POP_Zip'].append(contract['place_of_performance']['zip5'])
#     except:
#         us_dict['POP_Zip'].append(np.nan)
#     try:
#         us_dict['Recipient_Name'].append(contract['recipient']['recipient_name'])
#     except:
#         us_dict['Recipient_Name'].append(np.nan)
#     try:
#         us_dict['Total_Obligation'].append(contract['total_obligation'])
#     except:
#         us_dict['Total_Obligation'].append(np.nan)
# Out:
# 1
# Department of Transportation
# 2
# Department of Transportation
# 3
# Department of Transportation
# 4
# Department of Transportation
# 5
# Department of Transportation
# 6
# Department of Transportation
# 7
# Department of Transportation
# 8
# Department of Transportation
# 9
# Department of Transportation
# 10
# Department of Transportation
# 11
# Department of Transportation
# 12
# Department of Transportation
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-fe9d383da80a> in <module>()
#      44             us_dict['Total_Obligation'].append(np.nan)
#      45
# ---> 46         us_data = requests.get(url , json =params).json()
#      47         next_page = us_data['page_metadata']['has_next_page']
#      48
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1622             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1623         else:
# -> 1624             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1625         self._raise_ssl_error(self._ssl, result)
#    1626
#
# KeyboardInterrupt:

# %%
us_data_df = pd.DataFrame(us_dict)
us_data_df
# Out:
#                   Awarding_Agency  Category          POP_City  \
# 0    Department of Transportation  contract        WASHINGTON
# 1    Department of Transportation  contract         BALTIMORE
# 2    Department of Transportation  contract         BALTIMORE
# 3    Department of Transportation  contract           ORLANDO
# 4    Department of Transportation  contract            MOJAVE
# 5    Department of Transportation  contract          FLUSHING
# 6    Department of Transportation  contract            DALLAS
# 7    Department of Transportation  contract  SAINT PETERSBURG
# 8    Department of Transportation  contract     OKLAHOMA CITY
# 9    Department of Transportation  contract        WASHINGTON
# 10   Department of Transportation  contract            TUSTIN
# 11   Department of Transportation  contract     OKLAHOMA CITY
# 12   Department of Transportation  contract  COLORADO SPRINGS
# 13   Department of Transportation  contract          FLUSHING
# 14   Department of Transportation  contract          PRESCOTT
# 15   Department of Transportation  contract     OKLAHOMA CITY
# 16   Department of Transportation  contract            NORMAN
# 17   Department of Transportation  contract     OKLAHOMA CITY
# 18   Department of Transportation  contract     OKLAHOMA CITY
# 19   Department of Transportation  contract     NICHOLS HILLS
# 20   Department of Transportation  contract          FLUSHING
# 21   Department of Transportation  contract     OKLAHOMA CITY
# 22   Department of Transportation  contract     OKLAHOMA CITY
# 23   Department of Transportation  contract     OKLAHOMA CITY
# 24   Department of Transportation  contract             BOISE
# 25   Department of Transportation  contract        THE COLONY
# 26   Department of Transportation  contract        LOUISVILLE
# 27   Department of Transportation  contract          FLUSHING
# 28   Department of Transportation  contract     OVERLAND PARK
# 29   Department of Transportation  contract     OKLAHOMA CITY
# ..                            ...       ...               ...
# 470  Department of Transportation  contract        WASHINGTON
# 471  Department of Transportation  contract        WASHINGTON
# 472  Department of Transportation  contract        CHESAPEAKE
# 473  Department of Transportation  contract         CHANTILLY
# 474  Department of Transportation  contract        WASHINGTON
# 475  Department of Transportation  contract         SUNNYVALE
# 476  Department of Transportation  contract          TORRANCE
# 477  Department of Transportation  contract        WASHINGTON
# 478  Department of Transportation  contract        WASHINGTON
# 479  Department of Transportation  contract        WASHINGTON
# 480  Department of Transportation  contract       SANTA CLARA
# 481  Department of Transportation  contract           NAGUABO
# 482  Department of Transportation  contract        WASHINGTON
# 483  Department of Transportation  contract  PLYMOUTH MEETING
# 484  Department of Transportation  contract           MC LEAN
# 485  Department of Transportation  contract            URBANA
# 486  Department of Transportation  contract           MC LEAN
# 487  Department of Transportation  contract        PITTSBURGH
# 488  Department of Transportation  contract        WASHINGTON
# 489  Department of Transportation  contract        WASHINGTON
# 490  Department of Transportation  contract        ALEXANDRIA
# 491  Department of Transportation  contract            MCLEAN
# 492  Department of Transportation  contract        WASHINGTON
# 493  Department of Transportation  contract   COLLEGE STATION
# 494  Department of Transportation  contract   COLLEGE STATION
# 495  Department of Transportation  contract          COLUMBUS
# 496  Department of Transportation  contract         CAMBRIDGE
# 497  Department of Transportation  contract           FAIRFAX
# 498  Department of Transportation  contract            RESTON
# 499  Department of Transportation  contract        WASHINGTON
#
#                 POP_State POP_Zip  \
# 0    DISTRICT OF COLUMBIA   20591
# 1                MARYLAND   21230
# 2                MARYLAND   21230
# 3                 FLORIDA   32822
# 4              CALIFORNIA   93501
# 5                NEW YORK   11371
# 6                   TEXAS   75261
# 7                 FLORIDA   33710
# 8                OKLAHOMA   73169
# 9    DISTRICT OF COLUMBIA   20591
# 10             CALIFORNIA   92780
# 11               OKLAHOMA   73169
# 12               COLORADO   80916
# 13               NEW YORK   11371
# 14                ARIZONA   86301
# 15               OKLAHOMA   73169
# 16               OKLAHOMA   73071
# 17               OKLAHOMA   73169
# 18               OKLAHOMA   73169
# 19               OKLAHOMA   73116
# 20               NEW YORK   11371
# 21               OKLAHOMA   73104
# 22               OKLAHOMA   73169
# 23               OKLAHOMA   73169
# 24                  IDAHO   83705
# 25                  TEXAS   75056
# 26               COLORADO   80027
# 27               NEW YORK   11371
# 28                 KANSAS   66214
# 29               OKLAHOMA   73169
# ..                    ...     ...
# 470  DISTRICT OF COLUMBIA   20591
# 471  DISTRICT OF COLUMBIA   20001
# 472              VIRGINIA   23320
# 473              VIRGINIA   20152
# 474  DISTRICT OF COLUMBIA   20591
# 475            CALIFORNIA   94085
# 476            CALIFORNIA   90505
# 477  DISTRICT OF COLUMBIA   20591
# 478  DISTRICT OF COLUMBIA   20591
# 479  DISTRICT OF COLUMBIA   20591
# 480            CALIFORNIA   95050
# 481           PUERTO RICO   00718
# 482  DISTRICT OF COLUMBIA   20024
# 483          PENNSYLVANIA   19462
# 484              VIRGINIA   22101
# 485              ILLINOIS   61801
# 486              VIRGINIA   22101
# 487          PENNSYLVANIA   15222
# 488  DISTRICT OF COLUMBIA   20590
# 489  DISTRICT OF COLUMBIA   20003
# 490              VIRGINIA   22301
# 491              VIRGINIA   22102
# 492  DISTRICT OF COLUMBIA   20590
# 493                 TEXAS   77845
# 494                 TEXAS   77843
# 495                  OHIO   43201
# 496         MASSACHUSETTS   02140
# 497              VIRGINIA   22031
# 498              VIRGINIA   20190
# 499  DISTRICT OF COLUMBIA   20006
#
#                                      Recipient_Name  \
# 0                                EVANS INCORPORATED
# 1                             MARYLAND MARITIME INC
# 2                             MARYLAND MARITIME INC
# 3                        SIMCOM INTERNATIONAL, INC.
# 4                    NATIONAL TEST PILOT SCHOOL INC
# 5                    FLIGHTSAFETY INTERNATIONAL INC
# 6                                CAE SIMUFLITE, INC
# 7                            SENSOR SYSTEMS, L.L.C.
# 8                              ONESIMUS DEFENSE LLC
# 9                       NEW BEDFORD PANORAMEX CORP.
# 10                    PVP ADVANCED EO SYSTEMS, INC.
# 11                                RIGIL CORPORATION
# 12                            RAMPART AVIATION, LLC
# 13                  FLIGHTSAFETY INTERNATIONAL INC.
# 14                            GUIDANCE ACADEMY, LLC
# 15                            MA TECH SERVICES INC.
# 16                        CNI GLOBAL SOLUTIONS, LLC
# 17             ATLANTIC FABRICATION AND DESIGN, LLC
# 18   METROPOLITAN AIR CONDITIONING SERVICE CO (INC)
# 19                    DISCOVERSOFT DEVELOPMENT, LLC
# 20                   FLIGHTSAFETY INTERNATIONAL INC
# 21             OKLAHOMA MEDICAL RESEARCH FOUNDATION
# 22                  SOUTHWEST SOLUTIONS GROUP, INC.
# 23                DALE ROGERS TRAINING CENTER, INC.
# 24              AVIATION SPECIALTIES UNLIMITED, INC
# 25                  SOUTHWEST SOLUTIONS GROUP, INC.
# 26                                     VAISALA INC.
# 27                   FLIGHTSAFETY INTERNATIONAL INC
# 28                                    SELEX ES INC.
# 29                                 IMMUNALYSIS CORP
# ..                                              ...
# 470                               ENVIRONAMICS, INC
# 471                               PSI SERVICES, LLC
# 472                               PITNEY BOWES INC.
# 473                  FOUR POINTS TECHNOLOGY, L.L.C.
# 474                                   WIRE2NET, LLC
# 475                                            ATAC
# 476                                      ACTA, INC.
# 477            ADVANCED MANAGEMENT TECHNOLOGY, INC.
# 478                                    NOBLIS, INC.
# 479                            LS TECHNOLOGIES, LLC
# 480                                            ATAC
# 481                       VERACITY ENGINEERING, LLC
# 482                BELLAMY MANAGEMENT SERVICES, LLC
# 483         AMEC ENVIRONMENT & INFRASTRUCTURE, INC.
# 484        ENGINEERING & SOFTWARE CONSULTANTS, INC.
# 485                APPLIED PAVEMENT TECHNOLOGY, INC
# 486        ENGINEERING & SOFTWARE CONSULTANTS, INC.
# 487                           HDR ENGINEERING, INC.
# 488                APPLIED PAVEMENT TECHNOLOGY, INC
# 489                                    WSP USA INC.
# 490                        ICF INCORPORATED, L.L.C.
# 491                        BOOZ ALLEN HAMILTON INC.
# 492                                    NOBLIS, INC.
# 493              TEXAS A&M TRANSPORTATION INSTITUTE
# 494              TEXAS A&M TRANSPORTATION INSTITUTE
# 495                     BATTELLE MEMORIAL INSTITUTE
# 496                     CAMBRIDGE SYSTEMATICS, INC.
# 497                        ICF INCORPORATED, L.L.C.
# 498                                    LEIDOS, INC.
# 499     INSTITUTE OF TRANSPORTATION ENGINEERS, INC.
#
#                                         Subtier_Agency Subtier_Code  \
# 0    Immediate Office of the Secretary of Transport...         6901
# 1                              Maritime Administration         6938
# 2                              Maritime Administration         6938
# 3                      Federal Aviation Administration         6920
# 4                      Federal Aviation Administration         6920
# 5                      Federal Aviation Administration         6920
# 6                      Federal Aviation Administration         6920
# 7                      Federal Aviation Administration         6920
# 8                      Federal Aviation Administration         6920
# 9                      Federal Aviation Administration         6920
# 10                     Federal Aviation Administration         6920
# 11                     Federal Aviation Administration         6920
# 12                     Federal Aviation Administration         6920
# 13                     Federal Aviation Administration         6920
# 14                     Federal Aviation Administration         6920
# 15                     Federal Aviation Administration         6920
# 16                     Federal Aviation Administration         6920
# 17                     Federal Aviation Administration         6920
# 18                     Federal Aviation Administration         6920
# 19                     Federal Aviation Administration         6920
# 20                     Federal Aviation Administration         6920
# 21                     Federal Aviation Administration         6920
# 22                     Federal Aviation Administration         6920
# 23                     Federal Aviation Administration         6920
# 24                     Federal Aviation Administration         6920
# 25                     Federal Aviation Administration         6920
# 26                     Federal Aviation Administration         6920
# 27                     Federal Aviation Administration         6920
# 28                     Federal Aviation Administration         6920
# 29                     Federal Aviation Administration         6920
# ..                                                 ...          ...
# 470                    Federal Aviation Administration         6920
# 471                    Federal Aviation Administration         6920
# 472                    Federal Aviation Administration         6920
# 473                    Federal Aviation Administration         6920
# 474                    Federal Aviation Administration         6920
# 475                    Federal Aviation Administration         6920
# 476                    Federal Aviation Administration         6920
# 477                    Federal Aviation Administration         6920
# 478                    Federal Aviation Administration         6920
# 479                    Federal Aviation Administration         6920
# 480                    Federal Aviation Administration         6920
# 481                    Federal Aviation Administration         6920
# 482                    Federal Aviation Administration         6920
# 483                     Federal Highway Administration         6925
# 484                     Federal Highway Administration         6925
# 485                     Federal Highway Administration         6925
# 486                     Federal Highway Administration         6925
# 487                     Federal Highway Administration         6925
# 488                     Federal Highway Administration         6925
# 489                     Federal Highway Administration         6925
# 490                     Federal Highway Administration         6925
# 491                     Federal Highway Administration         6925
# 492                     Federal Highway Administration         6925
# 493                     Federal Highway Administration         6925
# 494                     Federal Highway Administration         6925
# 495                     Federal Highway Administration         6925
# 496                     Federal Highway Administration         6925
# 497                     Federal Highway Administration         6925
# 498                     Federal Highway Administration         6925
# 499                     Federal Highway Administration         6925
#
#     Total_Obligation
# 0          745068.00
# 1          520169.00
# 2          662420.00
# 3           39520.00
# 4           29950.00
# 5           59200.00
# 6            7693.00
# 7          211847.00
# 8           13989.00
# 9          490200.00
# 10         106500.00
# 11         605377.86
# 12          15830.00
# 13         196080.00
# 14          13675.12
# 15          68160.00
# 16        2673732.36
# 17              0.00
# 18         477978.00
# 19          68000.00
# 20          37000.00
# 21           3672.00
# 22           4527.95
# 23        1704732.69
# 24          12770.00
# 25           5630.01
# 26         612708.00
# 27          15222.00
# 28          77471.16
# 29          12300.00
# ..               ...
# 470         45690.00
# 471       1042526.00
# 472        171805.00
# 473        357500.00
# 474         13421.77
# 475         47484.29
# 476         65022.00
# 477        899801.76
# 478      10230341.03
# 479       3026610.70
# 480        115000.00
# 481         65000.00
# 482         88500.00
# 483        173847.33
# 484        123340.98
# 485        267574.80
# 486       2250000.00
# 487        373113.79
# 488        346608.00
# 489        225343.45
# 490        180200.00
# 491        221344.49
# 492        599352.00
# 493        249968.00
# 494        496921.00
# 495        289339.00
# 496        445082.00
# 497        749952.00
# 498        440248.45
# 499        400000.00
#
# [500 rows x 9 columns]

# %%
# us_data_df.to_csv('us_data.csv')

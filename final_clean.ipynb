# %%
import json
import requests
import pandas as pd
import numpy as np

import sqlite3

# %%
conn = sqlite3.connect('data.sqlite')
us_data_df = pd.read_sql_query("SELECT * FROM department_contracts", conn)
us_data_df = us_data_df.drop(['level_0', 'index'], axis=1)
us_data_df = us_data_df[np.isfinite(us_data_df['Latitude'])]
us_data_df.head()
# Out:
#                 Awarding_Agency  Category  Contract_ID Description   POP_City  \
# 1  Department of Transportation  contract        31520        None  BALTIMORE
# 2  Department of Transportation  contract        31521        None  BALTIMORE
# 3  Department of Transportation  contract        31525        None    ORLANDO
# 4  Department of Transportation  contract        31526        None     MOJAVE
# 5  Department of Transportation  contract        31527        None   FLUSHING
#
#     POP_State POP_Zip                  Recipient_Name  \
# 1    MARYLAND   21230           MARYLAND MARITIME INC
# 2    MARYLAND   21230           MARYLAND MARITIME INC
# 3     FLORIDA   32822      SIMCOM INTERNATIONAL, INC.
# 4  CALIFORNIA   93501  NATIONAL TEST PILOT SCHOOL INC
# 5    NEW YORK   11371  FLIGHTSAFETY INTERNATIONAL INC
#
#                     Subtier_Agency Subtier_Code Total_Obligation   Latitude  \
# 1          Maritime Administration         6938        520169.00  39.263517
# ...

# %%
doa_df = us_data_df.loc[us_data_df['Awarding_Agency'] == 'Department of Agriculture']
doa_df['Total_Obligation'] = doa_df['Total_Obligation'].apply(pd.to_numeric)
doa_df = doa_df.sort_values(by=['Total_Obligation'], ascending=False)
doa_df = doa_df.head(10)

# doa_df
print(doa_sum)
# Out:
# 310361332.13000005
# C:\Users\jdgon\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
dot_df = us_data_df.loc[us_data_df['Awarding_Agency'] == 'Department of Transportation']
dot_df['Total_Obligation'] = dot_df['Total_Obligation'].apply(pd.to_numeric)
dot_df = dot_df.sort_values(by=['Total_Obligation'], ascending=False)
dot_df = dot_df.head(10)
# Out:
# C:\Users\jdgon\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                     Awarding_Agency  Category  Contract_ID Description  \
# 65960  Department of Transportation  contract      8208959        None
# 270    Department of Transportation  contract       200448        None
# 74219  Department of Transportation  contract       200448        None
# 5919   Department of Transportation  contract     13812906        None
# 31126  Department of Transportation  contract     13810617        None
# 36137  Department of Transportation  contract        31597        None
# 61     Department of Transportation  contract        31597        None
# ...

# %%
doi_df = us_data_df.loc[us_data_df['Awarding_Agency'] == 'Department of the Interior']
doi_df['Total_Obligation'] = doi_df['Total_Obligation'].apply(pd.to_numeric)
doi_df = doi_df.sort_values(by=['Total_Obligation'], ascending=False)
doi_df = doi_df.head(10)
# Out:
# C:\Users\jdgon\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
doi_sum = doi_df['Total_Obligation'].sum()
dot_sum = dot_df['Total_Obligation'].sum()
doa_sum = doa_df['Total_Obligation'].sum()
total_sum = doi_sum + dot_sum + doa_sum
doi_df['Percentage_of_Total'] = ''
doi_df['Percentage_of_Dept'] = ''

for index, row in doi_df.iterrows():    
    
    row['Percentage_of_Total'].append(int(row['Total_Obligation']) / total_sum)

    
doi_df


# top = [doi_df, doa_df, dot_df]
# top_ten_df = pd.concat(top)
# # top_ten_df = top_ten_df.drop(['index', 'level_0'], axis=1)


# top_ten_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-71e8c692f2f3> in <module>()
#       8 for index, row in doi_df.iterrows():
#       9
# ---> 10     row['Percentage_of_Total'].append(int(row['Total_Obligation']) / total_sum)
#      11
#      12
#
# AttributeError: 'str' object has no attribute 'append'

# %%
conn = sqlite3.connect('data.sqlite')

top_ten_df.to_sql("top_ten", conn, if_exists="replace")
us_data_df.to_sql("lat_lon", conn, if_exists="replace")
